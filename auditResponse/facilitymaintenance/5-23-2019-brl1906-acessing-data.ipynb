# %%
import warnings
import datadotworld as dw
import pandas as pd

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Access broader dataset via [data.world](https://data.world) & load into a dataframe  is available in addition to the period based data in the excel file in the data folder in project

# %%
dataset = dw.load_dataset('dgs-kpis/fmd-maintenance')
dataframe = dataset.dataframes['archibus_maintenance_data']

# %% [markdown]
# ## Inspect the size of the dataset

# %%
for value, label in zip(dataframe.shape,['row','column']):
    print(f'{value} {label}s')
# Out:
# 88563 rows
# 92 columns

# %% [markdown]
# ## Observe the first 10 ros of the dataset

# %%
dataframe.head(10)
# Out:
#                             ac_id  act_labor_hours  activity_log_id  \
# 0  2029-000000-1982-709583-609036              0.0         119033.0
# 1  1001-000000-3572-772800-603051              0.0         119023.0
# 2  1001-000000-3572-772800-603051              0.0         119026.0
# 3  2029-000000-1982-709519-603026              0.0         119029.0
# 4  2029-000000-1982-709500-603026              0.0         119032.0
# 5  2029-000000-1982-709571-603026              0.0         119035.0
# 6  2029-000000-1982-709572-603026              0.0         119037.0
# 7  2029-000000-1982-709585-603026              0.0         119038.0
# 8  2029-000000-1982-709518-603026              0.0         119040.0
# 9  1001-000000-1982-192500-603016              0.0         118974.0
#
#                 activity_type  allow_work_on_holidays   bl_id cause_type  \
# 0  SERVICE DESK - MAINTENANCE                   False  B00063        NaN
# ...
